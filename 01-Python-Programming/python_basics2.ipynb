# %%
# control structures

# %%
age = 21

# %%
if age>= 18:
    print("You are eligible for voting")
# Out:
# You are eligible for voting

# %%
age =16

# %%
if age>= 18:
    print("You are eligible for voting")
else:
    print("You are not eligible")
# Out:
# You are not eligible

# %%
exp = 15

# %%
if exp>=0 and exp<=1:
    print("You are eligible as Trainee")
elif exp>1 and exp<=3:
    print("You are eligible as Data Analyst")
elif exp>3 and exp<=6:
    print("You are eligible as Data Scientist")
elif exp>6 and exp<=10:
    print("You are eligible as Sr. Data Scientist")
elif exp>10 and exp<=12:
    print("You are eligible as AI Engineer")
else:
    print("You are elgible for Project Manager")
# Out:
# You are elgible for Project Manager

# %%
# Nested if
amount = 2000
balance = 10000
bank = 'sbi'
atm = 'yes'
pwd = 1234

# %%
if atm == 'yes':
    if pwd == 1234:
        if bank == 'sbi':
            if amount <= balance:
                print("collect the cash!")
            else:
                print("Insufficient balance")
        else:
            print("card is deactivated")
    else:
        print("Incorrect password")
else:
    print("Insert your card properly")
# Out:
# Insert your card properly

# %%
# for loop
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
age = [24, 28, 36, 45, 12]
age
# Out:
# [24, 28, 36, 45, 12]

# %%
for i in age:
    print(i)
# Out:
# 24
# 28
# 36
# 45
# 12

# %%
salaries = [25000, 36000, 45000, 75000, 60000]

# %%
for i in salaries:
    if i >= 30000:
        print(i)
# Out:
# 36000
# 45000
# 75000
# 60000

# %%
# calculate the average using len, sum and print the data who are above average

# %%
avg = sum(salaries)/len(salaries)
avg
# Out:
# 48200.0

# %%
for i in salaries:
    if i >= avg:
        print(i)
# Out:
# 75000
# 60000

# %%
# functions

# %%
# create the function x square
def f1(x):
    return x ** 2

# %%
f1(-3.6)
# Out:
# 12.96

# %%
f1(9.7)
# Out:
# 94.08999999999999

# %%
# create function of y = 2x + 1
def f2(x):
    y = 2*x + 1
    return y

# %%
f2(3)
# Out:
# 7

# %%
f2(-2.5)
# Out:
# -4.0

# %%
def f3(x,y,z):
    w = (x+y+z)/3
    return w

# %%
f3(2,4,6)
# Out:
# 4.0

# %%
salaries = [25000, 36000, 45000, 75000, 60000]

# %%
def mean(salaries):
    avg = sum(salaries)/len(salaries)
    return avg

# %%
mean(salaries)
# Out:
# 48200.0

# %%
age = (24,32,36,75,12)

# %%
mean(age)
# Out:
# 35.8
