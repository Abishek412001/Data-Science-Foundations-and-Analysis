# %%
# list  ----> any kind of values 
#     0   1   2     3    4       5     6
j1 = [10,20, 36.5, 18, -12.4, 'cat', True]
j1
# Out:
# [10, 20, 36.5, 18, -12.4, 'cat', True]

# %%
type(j1)
# Out:
# list

# %%
len(j1) # count the number of values
# Out:
# 7

# %%
j1[0] # accessing the values based on index
# Out:
# 10

# %%
j1[5]
# Out:
# 'cat'

# %%
j1[5] = 40 # we can modified values
j1
# Out:
# [10, 20, 36.5, 18, -12.4, 40, True]

# %%
# how to add the values
j1.append(30) #adds the value directly at last
j1
# Out:
# [10, 20, 36.5, 18, -12.4, 40, True, 30]

# %%
j1.insert(4,100)  # index, value
j1
# Out:
# [10, 20, 36.5, 18, 100, -12.4, 40, True, 30]

# %%
# how to delete the values
j1.pop()  # last value removed
j1
# Out:
# [10, 20, 36.5, 18, 100, -12.4, 40, True]

# %%
j1.pop(5) # based on the index
j1
# Out:
# [10, 20, 36.5, 18, 100, 40, True]

# %%
j1.remove(True)
j1
# Out:
# [10, 20, 36.5, 18, 100, 40]

# %%
j1.sort()
j1
# Out:
# [10, 18, 20, 36.5, 40, 100]

# %%
# tuples
t1 = (24,26,34,14,74,50,14)
t1
# Out:
# (24, 26, 34, 14, 74, 50, 14)

# %%
type(t1)
# Out:
# tuple

# %%
t1.count(14) # counting the total number of times
# Out:
# 2

# %%
t1.index(74)
# Out:
# 4

# %%
len(t1)
# Out:
# 7

# %%
sum(t1)
# Out:
# 236

# %%
# dictionary
d1 = {"Male": 1, "Female": 2}
d1
# Out:
# {'Male': 1, 'Female': 2}

# %%
type(d1)
# Out:
# dict

# %%
d1.keys()
# Out:
# dict_keys(['Male', 'Female'])

# %%
d1.values()
# Out:
# dict_values([1, 2])

# %%
d2 = {"ID": [101,102,103], "Age": [24,56,13], 'Gender': ['M','M','F']}
d2
# Out:
# {'ID': [101, 102, 103], 'Age': [24, 56, 13], 'Gender': ['M', 'M', 'F']}

# %%
d2.keys()
# Out:
# dict_keys(['ID', 'Age', 'Gender'])

# %%
d2.values()
# Out:
# dict_values([[101, 102, 103], [24, 56, 13], ['M', 'M', 'F']])

# %%
d2["Age"]
# Out:
# [24, 56, 13]

# %%
d2["Age"][0] = 34

# %%
d2["Age"][0]
# Out:
# 34

# %%
s1 = {24,'f',54,19,36,"m" ,19,36,63,36}
s1
# Out:
# {19, 24, 36, 54, 63, 'f', 'm'}

# %%
type(s1)
# Out:
# set
